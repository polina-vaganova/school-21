# %% [markdown]
# # **Movielens analytics report**

# %% [markdown]
# ## Preparation:

# %% [markdown]
# Import necessary modules:

# %%
import os
import sys

# %% [markdown]
# Add path to the source:

# %%
sys.path.append(
    os.path.abspath(
        os.path.join(
            os.getcwd(),
            os.pardir,
        ),
    ),
)

# %% [markdown]
# Import necessary entities:

# %%
from src.movielens_analysis.models.tag import *
from src.movielens_analysis.models.link import *
from src.movielens_analysis.models.user import *
from src.movielens_analysis.models.movie import *
from src.movielens_analysis.models.rating import *

# %% [markdown]
# Consider the functional of several classes that will help us analyze movie data.

# %% [markdown]
# ## `Link` class:

# %% [markdown]
# Create `Link` class instance:

# %%
link_inst: Link = Link(file_path="../data/datasets/", )

# %%
# %%timeit -n 10 -r 3
link_inst: Link = Link(file_path="../data/datasets/", )
# Out:
# 467 ns ± 180 ns per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Load all data for class instance:

# %%
# %%capture
link_inst.load_data()
link_inst.load_movies_ids()
link_inst.load_imdb_ids()
link_inst.load_tmdb_ids()
link_inst.load_movies_data(movies_ids=link_inst.imdb_ids[: 25], )

# %%
# %%timeit -n 2 -r 3
# %%capture
link_inst.load_data()
link_inst.load_movies_ids()
link_inst.load_imdb_ids()
link_inst.load_tmdb_ids()
link_inst.load_movies_data(movies_ids=link_inst.imdb_ids[: 25], )
# Out:
# 29.2 s ± 509 ms per loop (mean ± std. dev. of 3 runs, 2 loops each)

# %% [markdown]
# Print all loaded data of class instance:

# %%
link_inst.print_data()
# Out:
# row index: 1, data: 1,0114709,862
# row index: 2, data: 2,0113497,8844
# row index: 3, data: 3,0113228,15602
# row index: 4, data: 4,0114885,31357
# row index: 5, data: 5,0113041,11862
# row index: 6, data: 6,0113277,949
# row index: 7, data: 7,0114319,11860
# row index: 8, data: 8,0112302,45325
# row index: 9, data: 9,0114576,9091
# row index: 10, data: 10,0113189,710
# row index: 11, data: 11,0112346,9087
# row index: 12, data: 12,0112896,12110
# row index: 13, data: 13,0112453,21032
# row index: 14, data: 14,0113987,10858
# row index: 15, data: 15,0112760,1408
# row index: 16, data: 16,0112641,524
# row index: 17, data: 17,0114388,4584
# row index: 18, data: 18,0113101,5
# row index: 19, data: 19,0112281,9273
# row index: 20, data: 20,0113845,11517
# row index: 21, data: 21,0113161,8012
# row index: 22, data: 22,0112722,1710
# row index: 23, data: 23,0112401,9691
# row index: 24, data: 24,0114168,12665
# row index: 25, data: 25,0113627,451
# row index: 26, data: 26,0114057,16420
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
link_inst.print_data()
# Out:
# The slowest run took 11.60 times longer than the fastest. This could mean that an intermediate result is being cached.
# 87.9 ms ± 87.6 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
link_inst.print_movies_ids()
# Out:
# row index: 1, movie_id: 1
# row index: 2, movie_id: 2
# row index: 3, movie_id: 3
# row index: 4, movie_id: 4
# row index: 5, movie_id: 5
# row index: 6, movie_id: 6
# row index: 7, movie_id: 7
# row index: 8, movie_id: 8
# row index: 9, movie_id: 9
# row index: 10, movie_id: 10
# row index: 11, movie_id: 11
# row index: 12, movie_id: 12
# row index: 13, movie_id: 13
# row index: 14, movie_id: 14
# row index: 15, movie_id: 15
# row index: 16, movie_id: 16
# row index: 17, movie_id: 17
ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
link_inst.print_extracted_fields()
# Out:
# Extracted movies fields: ['gross', 'title', 'budget', 'rating', 'writer', 'runtime', 'release', 'country', 'director', 'language']

# %%
# %%timeit -n 10 -r 3
# %%capture
link_inst.print_extracted_fields()
# Out:
# 637 μs ± 151 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
link_inst.print_movies_data()
# Out:
# row index: 1, movie_data: ['0114885', '$81,452,156', 'В ожидании выдоха', '$16,000,000', '6.0', 'Forest Whitaker', '2 hours 4 minutes', 'December 22, 1995 ', 'United States', 'Forest Whitaker', 'english']
# row index: 2, movie_data: ['0114709', '$394,436,586', 'История игрушек', '$30,000,000', '8.3', 'John Lasseter', '1 hour 21 minutes', 'December 22, 1995 ', 'United States', 'John Lasseter', 'english']
# row index: 3, movie_data: ['0114576', '$64,350,171', 'Внeзапная смерть', '$35,000,000', '5.9', 'Peter Hyams', '1 hour 51 minutes', 'December 22, 1995 ', 'United States', 'Peter Hyams', 'english']
# row index: 4, movie_data: ['0114388', '$134,582,776', 'Разум и чувства', '$16,000,000', '7.7', 'Ang Lee', '2 hours 16 minutes', 'January 26, 1996 ', 'United Kingdom', 'Ang Lee', 'english']
# row index: 5, movie_data: ['0114319', '$53,696,959', 'Сабрина', '$58,000,000', '6.3', 'Sydney Pollack', '2 hours 7 minutes', 'December 15, 1995 ', 'Germany', 'Sydney Pollack', 'english']
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
link_inst.print_movies_data()
# Out:
# 1.2 ms ± 119 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the most popular movie directors:

# %%
[
    print(
        f"director: {movies_director}, count of created movies: {movies_cnt}",
    )
    for movies_director, movies_cnt
    in link_inst.get_popular_directors().items()
];
# Out:
# director: Forest Whitaker, count of created movies: 1
# director: John Lasseter, count of created movies: 1
# director: Peter Hyams, count of created movies: 1
# director: Ang Lee, count of created movies: 1
# director: Sydney Pollack, count of created movies: 1
# director: Victor Salva, count of created movies: 1
# director: Oliver Stone, count of created movies: 1
# director: Joseph Ruben, count of created movies: 1
# director: Mike Figgis, count of created movies: 1
# director: Joe Johnston, count of created movies: 1

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(
        f"director: {movies_director}, count of created movies: {movies_cnt}",
    )
    for movies_director, movies_cnt
    in link_inst.get_popular_directors().items()
]
# Out:
# 1.71 ms ± 267 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the most expensive movies:

# %%
[
    print(f"movie title: {movie_title}, movie budget: {movie_budget}", )
    for movie_title, movie_budget
    in link_inst.get_most_expensive_movies().items()
];
# Out:
# movie title: Остров головорезов, movie budget: $98,000,000
# movie title: Денежный поезд, movie budget: $68,000,000
# movie title: Джуманджи, movie budget: $65,000,000
# movie title: Американский президент, movie budget: $62,000,000
# movie title: Схватка, movie budget: $60,000,000
# movie title: Золотой глаз, movie budget: $60,000,000
# movie title: Сабрина, movie budget: $58,000,000
# movie title: Казино, movie budget: $52,000,000
# movie title: Наемные убийцы, movie budget: $50,000,000
# movie title: Никсон, movie budget: $44,000,000

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, movie budget: {movie_budget}", )
    for movie_title, movie_budget
    in link_inst.get_most_expensive_movies().items()
]
# Out:
# 1.42 ms ± 252 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the most profitable movies:

# %%
[
    print(f"movie title: {movie_title}, movie profit: ${movie_profit}", )
    for movie_title, movie_profit
    in link_inst.get_most_profitable_movies().items()
];
# Out:
# movie title: История игрушек, movie profit: $364436586
# movie title: Золотой глаз, movie profit: $292194034
# movie title: Джуманджи, movie profit: $197821940
# movie title: Эйс Вентура 2: Когда зовёт природа, movie profit: $182385533
# movie title: Схватка, movie profit: $127436818
# movie title: Разум и чувства, movie profit: $118582776
# movie title: Достать коротышку, movie profit: $84851622
# movie title: В ожидании выдоха, movie profit: $65452156
# movie title: Казино, movie profit: $64112375
# movie title: Отец невесты 2, movie profit: $46594107

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, movie profit: ${movie_profit}", )
    for movie_title, movie_profit
    in link_inst.get_most_profitable_movies().items()
]
# Out:
# 1.23 ms ± 215 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the longest movies:

# %%
[
    print(f"movie title: {movie_title}, movie runtime: {movie_runtime}", )
    for movie_title, movie_runtime
    in link_inst.get_most_longest_movies().items()
];
# Out:
# movie title: Никсон, movie runtime: 3 hours 12 minutes
# movie title: Казино, movie runtime: 2 hours 58 minutes
# movie title: Схватка, movie runtime: 2 hours 50 minutes
# movie title: Разум и чувства, movie runtime: 2 hours 16 minutes
# movie title: Наемные убийцы, movie runtime: 2 hours 13 minutes
# movie title: Золотой глаз, movie runtime: 2 hours 10 minutes
# movie title: Сабрина, movie runtime: 2 hours 7 minutes
# movie title: В ожидании выдоха, movie runtime: 2 hours 4 minutes
# movie title: Остров головорезов, movie runtime: 2 hours 4 minutes
# movie title: Имитатор, movie runtime: 2 hours 3 minutes

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, movie runtime: {movie_runtime}", )
    for movie_title, movie_runtime
    in link_inst.get_most_longest_movies().items()
]
# Out:
# 1.26 ms ± 252 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the most expensive minute movies:

# %%
[
    print(f"movie title: {movie_title}, movie minute cost: ${movie_min_cost}", )
    for movie_title, movie_min_cost
    in link_inst.get_top_cost_per_minute_movies().items()
];
# Out:
# movie title: Остров головорезов, movie minute cost: $790322.58
# movie title: Джуманджи, movie minute cost: $625000.0
# movie title: Денежный поезд, movie minute cost: $618181.82
# movie title: Американский президент, movie minute cost: $543859.65
# movie title: Золотой глаз, movie minute cost: $461538.46
# movie title: Сабрина, movie minute cost: $456692.91
# movie title: Наемные убийцы, movie minute cost: $375939.85
# movie title: История игрушек, movie minute cost: $370370.37
# movie title: Схватка, movie minute cost: $352941.18
# movie title: Дракула: Мёртвый и довольный, movie minute cost: $340909.09

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, movie minute cost: ${movie_min_cost}", )
    for movie_title, movie_min_cost
    in link_inst.get_top_cost_per_minute_movies().items()
]
# Out:
# 1.74 ms ± 258 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# ## `Movie` class:

# %% [markdown]
# Create `Movie` class instance:

# %%
movie_inst: Movie = Movie(file_path="../data/datasets/", )

# %%
# %%timeit -n 10 -r 3
movie_inst: Movie = Movie(file_path="../data/datasets/", )
# Out:
# 683 ns ± 309 ns per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Load all data for class instance:

# %%
movie_inst.load_data()
movie_inst.load_movies_ids()
movie_inst.load_titles()
movie_inst.load_genres()

# %%
# %%timeit -n 10 -r 3
movie_inst.load_data()
movie_inst.load_movies_ids()
movie_inst.load_titles()
movie_inst.load_genres()
# Out:
# 3.25 ms ± 510 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
#
ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
movie_inst.print_genres()
# Out:
# row index: 1, movie genres: ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy']
# row index: 2, movie genres: ['Adventure', 'Children', 'Fantasy']
# row index: 3, movie genres: ['Comedy', 'Romance']
# row index: 4, movie genres: ['Comedy', 'Drama', 'Romance']
# row index: 5, movie genres: ['Comedy']
# row index: 6, movie genres: ['Action', 'Crime', 'Thriller']
# row index: 7, movie genres: ['Comedy', 'Romance']
# row index: 8, movie genres: ['Adventure', 'Children']
# row index: 9, movie genres: ['Action']
# row index: 10, movie genres: ['Action', 'Adventure', 'Thriller']
# row index: 11, movie genres: ['Comedy', 'Drama', 'Romance']
# row index: 12, movie genres: ['Comedy', 'Horror']
# row index: 13, movie genres: ['Adventure', 'Animation', 'Children']
# row index: 14, movie genres: ['Drama']
# row index: 15, movie genres: ['Action', 'Adventure', 'Romance']
# row index: 16, movie genres: ['Crime', 'Drama']
# row index: 17, movie genres: ['Drama', 'Romance']
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
movie_inst.print_genres()
# Out:
# The slowest run took 28.40 times longer than the fastest. This could mean that an intermediate result is being cached.
# 228 ms ± 258 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the years and the number of movies released in those years:

# %%
[
    print(f"movie year: {movie_year}, movies count: {movies_cnt}", )
    for movie_year, movies_cnt
    in movie_inst.get_release_years_movie_counts().items()
];
# Out:
# movie year: 1995, movies count: 224
# movie year: 1994, movies count: 184
# movie year: 1996, movies count: 181
# movie year: 1993, movies count: 101
# movie year: 1992, movies count: 23
# movie year: 1990, movies count: 15
# movie year: 1991, movies count: 15
# movie year: 1989, movies count: 14
# movie year: 1986, movies count: 9
# movie year: 1982, movies count: 8
# movie year: 1940, movies count: 8
# movie year: 1957, movies count: 8
# movie year: 1987, movies count: 8
# movie year: 1980, movies count: 8
# movie year: 1981, movies count: 7
# movie year: 1988, movies count: 7
# movie year: 1979, movies count: 7
# movie year: 1955, movies count: 6
# movie year: 1959, movies count: 6
# movie year: 1968, movies count: 6
# movie year: 1997, movies count: 6
# movie year: 1939, movies count: 6
# movie year: 1985, movies count: 6
# movie year: 1967, movies count: 5
# movie year: 1965, movies count: 5
# movie year: 1951, movies count: 5
# movie year: 1958, movies count: 5
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie year: {movie_year}, movies count: {movies_cnt}", )
    for movie_year, movies_cnt
    in movie_inst.get_release_years_movie_counts().items()
]
# Out:
# 2.45 ms ± 120 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the occurrence of genres among movies:

# %%
[
    print(f"genre: {genre}, genres count: {genres_cnt}", )
    for genre, genres_cnt
    in movie_inst.get_genres_counts().items()
];
# Out:
# genre: Drama, genres count: 507
# genre: Comedy, genres count: 365
# genre: Romance, genres count: 208
# genre: Thriller, genres count: 179
# genre: Action, genres count: 158
# genre: Adventure, genres count: 126
# genre: Crime, genres count: 122
# genre: Children, genres count: 100
# genre: Fantasy, genres count: 69
# genre: Sci-Fi, genres count: 69
# genre: Mystery, genres count: 58
# genre: Musical, genres count: 53
# genre: Horror, genres count: 51
# genre: War, genres count: 48
# genre: Animation, genres count: 37
# genre: Documentary, genres count: 25
# genre: Western, genres count: 23
# genre: Film-Noir, genres count: 18
# genre: IMAX, genres count: 3

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"genre: {genre}, genres count: {genres_cnt}", )
    for genre, genres_cnt
    in movie_inst.get_genres_counts().items()
]
# Out:
# 1.69 ms ± 232 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of movies with the largest number of genres:

# %%
[
    print(f"movie title: {movie_title}, genres count: {genres_cnt}", )
    for movie_title, genres_cnt
    in movie_inst.get_most_genres_movies().items()
];
# Out:
# movie title: Strange Days (1995), genres count: 6
# movie title: Lion King, The (1994), genres count: 6
# movie title: Getaway, The (1994), genres count: 6
# movie title: Super Mario Bros. (1993), genres count: 6
# movie title: Beauty and the Beast (1991), genres count: 6
# movie title: All Dogs Go to Heaven 2 (1996), genres count: 6
# movie title: Space Jam (1996), genres count: 6
# movie title: Aladdin and the King of Thieves (1996), genres count: 6
# movie title: Toy Story (1995), genres count: 5
# movie title: Money Train (1995), genres count: 5

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, genres count: {genres_cnt}", )
    for movie_title, genres_cnt
    in movie_inst.get_most_genres_movies().items()
]
# Out:
# 1.51 ms ± 245 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of movies with the highest number of ratings received:

# %%
[
    print(f"movie title: {movie_title}, ratings count: {ratings_cnt}", )
    for movie_title, ratings_cnt
    in movie_inst.get_most_ratings_movies().items()
];
# Out:
# movie title: Usual Suspects, The (1995), ratings count: 4
# movie title: Pulp Fiction (1994), ratings count: 4
# movie title: Fugitive, The (1993), ratings count: 4
# movie title: Schindler's List (1993), ratings count: 4
# movie title: Aladdin (1992), ratings count: 4
# movie title: Batman (1989), ratings count: 4
# movie title: Silence of the Lambs, The (1991), ratings count: 4
# movie title: Beauty and the Beast (1991), ratings count: 4
# movie title: Fargo (1996), ratings count: 4
# movie title: Toy Story (1995), ratings count: 3

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, ratings count: {ratings_cnt}", )
    for movie_title, ratings_cnt
    in movie_inst.get_most_ratings_movies().items()
]
# Out:
# 15.4 ms ± 2.24 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of movies with the highest metric value:

# %%
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="min", ).items()
];
# Out:
# movie title: 5, metric value: 5.0
# movie title: 22, metric value: 5.0
# movie title: 86, metric value: 5.0
# movie title: 101, metric value: 5.0
# movie title: 125, metric value: 5.0
# movie title: 157, metric value: 5.0
# movie title: 160, metric value: 5.0
# movie title: 162, metric value: 5.0
# movie title: 168, metric value: 5.0
# movie title: 176, metric value: 5.0

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="min", ).items()
]
# Out:
# 33.9 ms ± 3.25 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="max", ).items()
];
# Out:
# movie title: 3, metric value: 5.0
# movie title: 5, metric value: 5.0
# movie title: 22, metric value: 5.0
# movie title: 36, metric value: 5.0
# movie title: 47, metric value: 5.0
# movie title: 50, metric value: 5.0
# movie title: 58, metric value: 5.0
# movie title: 86, metric value: 5.0
# movie title: 101, metric value: 5.0
# movie title: 110, metric value: 5.0

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="max", ).items()
]
# Out:
# 32.2 ms ± 608 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="mean", ).items()
];
# Out:
# movie title: 5, metric value: 5.0
# movie title: 22, metric value: 5.0
# movie title: 86, metric value: 5.0
# movie title: 101, metric value: 5.0
# movie title: 125, metric value: 5.0
# movie title: 157, metric value: 5.0
# movie title: 160, metric value: 5.0
# movie title: 162, metric value: 5.0
# movie title: 168, metric value: 5.0
# movie title: 176, metric value: 5.0

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="mean", ).items()
]
# Out:
# 31.5 ms ± 160 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="median", ).items()
];
# Out:
# movie title: 5, metric value: 5.0
# movie title: 22, metric value: 5.0
# movie title: 86, metric value: 5.0
# movie title: 101, metric value: 5.0
# movie title: 125, metric value: 5.0
# movie title: 157, metric value: 5.0
# movie title: 160, metric value: 5.0
# movie title: 162, metric value: 5.0
# movie title: 168, metric value: 5.0
# movie title: 176, metric value: 5.0

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="median", ).items()
]
# Out:
# 31.8 ms ± 431 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="var", ).items()
];
# Out:
# movie title: 914, metric value: 5.06
# movie title: 527, metric value: 3.42
# movie title: 647, metric value: 3.06
# movie title: 50, metric value: 2.42
# movie title: 222, metric value: 2.25
# movie title: 441, metric value: 2.25
# movie title: 466, metric value: 2.25
# movie title: 587, metric value: 2.25
# movie title: 296, metric value: 2.19
# movie title: 553, metric value: 2.0

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="var", ).items()
]
# Out:
# 45.4 ms ± 1.84 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="std", ).items()
];
# Out:
# movie title: 914, metric value: 2.25
# movie title: 527, metric value: 1.85
# movie title: 647, metric value: 1.75
# movie title: 50, metric value: 1.56
# movie title: 222, metric value: 1.5
# movie title: 441, metric value: 1.5
# movie title: 466, metric value: 1.5
# movie title: 587, metric value: 1.5
# movie title: 296, metric value: 1.48
# movie title: 553, metric value: 1.41

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, metric value: {metric_val}", )
    for movie_title, metric_val
    in movie_inst.get_top_ratings_metric_features(metric="std", ).items()
]
# Out:
# 32.5 ms ± 388 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# ## `Rating` class:

# %% [markdown]
# Create `Rating` class instance:

# %%
rating_inst: Rating = Rating(file_path="../data/datasets/", )

# %%
# %%timeit -n 10 -r 3
rating_inst: Rating = Rating(file_path="../data/datasets/", )
# Out:
# 357 ns ± 116 ns per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Load all data for class instance:

# %%
rating_inst.load_data()
rating_inst.load_users_ids()
rating_inst.load_movies_ids()
rating_inst.load_ratings()
rating_inst.load_timestamps()

# %%
# %%timeit -n 10 -r 3
rating_inst.load_data()
rating_inst.load_users_ids()
rating_inst.load_movies_ids()
rating_inst.load_ratings()
rating_inst.load_timestamps()
# Out:
# 1.68 ms ± 144 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Print all loaded data of class instance:

# %%
rating_inst.print_data()
# Out:
# row index: 1, data: 1,1,4.0,964982703
# row index: 2, data: 1,3,4.0,964981247
# row index: 3, data: 1,6,4.0,964982224
# row index: 4, data: 1,47,5.0,964983815
# row index: 5, data: 1,50,5.0,964982931
# row index: 6, data: 1,70,3.0,964982400
# row index: 7, data: 1,101,5.0,964980868
# row index: 8, data: 1,110,4.0,964982176
# row index: 9, data: 1,151,5.0,964984041
# row index: 10, data: 1,157,5.0,964984100
# row index: 11, data: 1,163,5.0,964983650
# row index: 12, data: 1,216,5.0,964981208
# row index: 13, data: 1,223,3.0,964980985
# row index: 14, data: 1,231,5.0,964981179
# row index: 15, data: 1,235,4.0,964980908
# row index: 16, data: 1,260,5.0,964981680
# row index: 17, data: 1,296,3.0,964982967
# row index: 18, data: 1,316,3.0,964982310
# row index: 19, data: 1,333,5.0,964981179
# row index: 20, data: 1,349,4.0,964982563
# row index: 21, data: 1,356,4.0,964980962
# row index: 22, data: 1,362,5.0,964982588
# row index: 23, data: 1,367,4.0,964981710
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
rating_inst.print_data()
# Out:
# The slowest run took 20.53 times longer than the fastest. This could mean that an intermediate result is being cached.
# 125 ms ± 140 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
rating_inst.print_ratings()
# Out:
# 25.5 ms ± 11.4 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
rating_inst.print_timestamps()
# Out:
# row index: 1, timestamp: 964982703
# row index: 2, timestamp: 964981247
# row index: 3, timestamp: 964982224
# row index: 4, timestamp: 964983815
# row index: 5, timestamp: 964982931
# row index: 6, timestamp: 964982400
# row index: 7, timestamp: 964980868
# row index: 8, timestamp: 964982176
# row index: 9, timestamp: 964984041
# row index: 10, timestamp: 964984100
# row index: 11, timestamp: 964983650
# row index: 12, timestamp: 964981208
# row index: 13, timestamp: 964980985
# row index: 14, timestamp: 964981179
# row index: 15, timestamp: 964980908
# row index: 16, timestamp: 964981680
# row index: 17, timestamp: 964982967
# row index: 18, timestamp: 964982310
# row index: 19, timestamp: 964981179
# row index: 20, timestamp: 964982563
# row index: 21, timestamp: 964980962
# row index: 22, timestamp: 964982588
# row index: 23, timestamp: 964981710
# row index: 24, timestamp: 964982363
# row index: 25, timestamp: 964980868
# row index: 26, timestamp: 964981909
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
rating_inst.print_timestamps()
# Out:
# The slowest run took 8.41 times longer than the fastest. This could mean that an intermediate result is being cached.
# 66.2 ms ± 55.1 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the years with the largest number of movies released:

# %%
[
    print(f"release year: {movies_year}, count of movies: {movies_cnt}", )
    for movies_year, movies_cnt
    in rating_inst.get_top_release_years().items()
];
# Out:
# release year: 1996, count of movies: 358
# release year: 1999, count of movies: 82
# release year: 2000, count of movies: 296
# release year: 2001, count of movies: 70
# release year: 2005, count of movies: 121
# release year: 2006, count of movies: 4
# release year: 2007, count of movies: 1
# release year: 2011, count of movies: 39
# release year: 2015, count of movies: 29

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"release year: {movies_year}, count of movies: {movies_cnt}", )
    for movies_year, movies_cnt
    in rating_inst.get_top_release_years().items()
]
# Out:
# 1.68 ms ± 176 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of the most popular ratings:

# %%
[
    print(f"rating: {rating}, rating count: {rating_cnt}", )
    for rating, rating_cnt
    in rating_inst.get_top_ratings().items()
];
# Out:
# rating: 0.5, rating count: 24
# rating: 1.0, rating count: 39
# rating: 1.5, rating count: 11
# rating: 2.0, rating count: 57
# rating: 2.5, rating count: 7
# rating: 3.0, rating count: 253
# rating: 3.5, rating count: 17
# rating: 4.0, rating count: 292
# rating: 4.5, rating count: 33
# rating: 5.0, rating count: 267

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"rating: {rating}, rating count: {rating_cnt}", )
    for rating, rating_cnt
    in rating_inst.get_top_ratings().items()
]
# Out:
# 1.27 ms ± 262 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# ## `Tag` class:

# %% [markdown]
# Create `Tag` class instance:

# %%
tag_inst: Tag = Tag(file_path="../data/datasets/", )

# %%
# %%timeit -n 10 -r 3
tag_inst: Tag = Tag(file_path="../data/datasets/", )
# Out:
# 663 ns ± 189 ns per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Load all data for class instance:

# %%
tag_inst.load_data()
tag_inst.load_users_ids()
tag_inst.load_movies_ids()
tag_inst.load_tags()
tag_inst.load_timestamps()

# %%
# %%timeit -n 2 -r 3
# %%capture
tag_inst.load_data()
tag_inst.load_users_ids()
tag_inst.load_movies_ids()
tag_inst.load_tags()
tag_inst.load_timestamps()
# Out:
# 3.52 ms ± 696 μs per loop (mean ± std. dev. of 3 runs, 2 loops each)

# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
tag_inst.print_movies_ids()
# Out:
# 28.4 ms ± 13.1 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
tag_inst.print_tags()
# Out:
# row index: 1, tag: funny
# row index: 2, tag: Highly quotable
# row index: 3, tag: will ferrell
# row index: 4, tag: Boxing story
# row index: 5, tag: MMA
# row index: 6, tag: Tom Hardy
# row index: 7, tag: drugs
# row index: 8, tag: Leonardo DiCaprio
# row index: 9, tag: Martin Scorsese
# row index: 10, tag: way too long
# row index: 11, tag: Al Pacino
# row index: 12, tag: gangster
# row index: 13, tag: mafia
# row index: 14, tag: Al Pacino
# row index: 15, tag: Mafia
# row index: 16, tag: holocaust
# row index: 17, tag: true story
# row index: 18, tag: twist ending
# row index: 19, tag: Anthony Hopkins
# row index: 20, tag: courtroom drama
# row index: 21, tag: twist ending
# row index: 22, tag: britpop
# row index: 23, tag: indie record label
# row index: 24, tag: music
# row index: 25, tag: dumpster diving
# row index: 26, tag: Sustainability
# row index: 27, tag: romantic comedy
# row index: 28, tag: wedding
# row index: 29, tag: painter
# row index: 30, tag: bloody
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
tag_inst.print_tags()
# Out:
# 28.5 ms ± 12.9 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
tag_inst.print_timestamps()
# Out:
# row index: 1, timestamp: 1445714994
# row index: 2, timestamp: 1445714996
# row index: 3, timestamp: 1445714992
# row index: 4, timestamp: 1445715207
# row index: 5, timestamp: 1445715200
# row index: 6, timestamp: 1445715205
# row index: 7, timestamp: 1445715054
# row index: 8, timestamp: 1445715051
# row index: 9, timestamp: 1445715056
# row index: 10, timestamp: 1169687325
# row index: 11, timestamp: 1462138765
# row index: 12, timestamp: 1462138749
# row index: 13, timestamp: 1462138755
# row index: 14, timestamp: 1461699306
# row index: 15, timestamp: 1461699303
# row index: 16, timestamp: 1455735472
# row index: 17, timestamp: 1455735479
# row index: 18, timestamp: 1456948283
# row index: 19, timestamp: 1457650696
# row index: 20, timestamp: 1457650711
# row index: 21, timestamp: 1457650682
# row index: 22, timestamp: 1457444500
# row index: 23, timestamp: 1457444592
# row index: 24, timestamp: 1457444609
# row index: 25, timestamp: 1455060381
# ...

# %%
# %%timeit -n 10 -r 3
# %%capture
tag_inst.print_timestamps()
# Out:
# The slowest run took 10.76 times longer than the fastest. This could mean that an intermediate result is being cached.
# 71.8 ms ± 67.6 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get the movies with tags the largest number of words:

# %%
[
    print(f"movie title: {movie_title}, words count: {words_cnt}", )
    for movie_title, words_cnt
    in tag_inst.get_most_words_tags().items()
]
# Out:
# movie title: Something for everyone in this one... saw it without and plan on seeing it with kids!, words count: 16
# movie title: the catholic church is the most corrupt organization in history, words count: 10
# movie title: Oscar (Best Music - Original Score), words count: 6
# movie title: based on a true story, words count: 5
# movie title: Everything you want is here, words count: 5
# movie title: seen more than once, words count: 4
# movie title: based on a play, words count: 4
# movie title: jay and silent bob, words count: 4
# movie title: political right versus left, words count: 4
# movie title: based on a book, words count: 4
# [None, None, None, None, None, None, None, None, None, None]

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}, words count: {words_cnt}", )
    for movie_title, words_cnt
    in tag_inst.get_most_words_tags().items()
]
# Out:
# 1.33 ms ± 175 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get the movies with tags with the longest length:

# %%
[
    print(f"movie title: {movie_title}", )
    for movie_title
    in tag_inst.get_longest_tags()
];
# Out:
# movie title: Something for everyone in this one... saw it without and plan on seeing it with kids!
# movie title: the catholic church is the most corrupt organization in history
# movie title: audience intelligence underestimated
# movie title: Oscar (Best Music - Original Score)
# movie title: assassin-in-training (scene)
# movie title: political right versus left
# movie title: Oscar (Best Cinematography)
# movie title: Everything you want is here
# movie title: representation of children
# movie title: Disney animated feature

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}", )
    for movie_title
    in tag_inst.get_longest_tags()
]
# Out:
# 1.2 ms ± 114 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get the movies with tags with the longest length and consisting of the largest
# number of words:

# %%
[
    print(f"movie title: {movie_title}", )
    for movie_title
    in tag_inst.get_most_words_and_longest_tags()
];
# Out:
# movie title: Something for everyone in this one... saw it without and plan on seeing it with kids!
# movie title: the catholic church is the most corrupt organization in history
# movie title: audience intelligence underestimated
# movie title: Oscar (Best Music - Original Score)
# movie title: Everything you want is here
# movie title: Oscar (Best Cinematography)
# movie title: political right versus left
# movie title: representation of children
# movie title: Disney animated feature
# movie title: Guardians of the Galaxy

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie title: {movie_title}", )
    for movie_title
    in tag_inst.get_most_words_and_longest_tags()
]
# Out:
# 1.51 ms ± 185 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get the most popular tags:

# %%
[
    print(f"movie tag: {movie_tag}, tag count: {tag_cnt}", )
    for movie_tag, tag_cnt
    in tag_inst.get_popular_tags().items()
];
# Out:
# movie tag: funny, tag count: 15
# movie tag: sci-fi, tag count: 14
# movie tag: dark comedy, tag count: 12
# movie tag: twist ending, tag count: 12
# movie tag: action, tag count: 10
# movie tag: atmospheric, tag count: 10
# movie tag: comedy, tag count: 10
# movie tag: superhero, tag count: 10
# movie tag: suspense, tag count: 10
# movie tag: Leonardo DiCaprio, tag count: 9

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie tag: {movie_tag}, tag count: {tag_cnt}", )
    for movie_tag, tag_cnt
    in tag_inst.get_popular_tags().items()
]
# Out:
# 2.03 ms ± 56.5 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get the tags with the word needed word ` in `:

# %%
[
    print(f"movie tag: {movie_tag}", )
    for movie_tag
    in tag_inst.get_unique_with_word_tags(word=" in ", )
];
# Out:
# movie tag: Something for everyone in this one... saw it without and plan on seeing it with kids!
# movie tag: heroine in tight suit
# movie tag: the catholic church is the most corrupt organization in history

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie tag: {movie_tag}", )
    for movie_tag
    in tag_inst.get_unique_with_word_tags(word=" in ", )
]
# Out:
# 1.39 ms ± 190 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"movie tag: {movie_tag}", )
    for movie_tag
    in tag_inst.get_unique_with_word_tags(word=" the ", )
];
# Out:
# movie tag: Guardians of the Galaxy
# movie tag: end of the world
# movie tag: lord of the rings
# movie tag: the catholic church is the most corrupt organization in history

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"movie tag: {movie_tag}", )
    for movie_tag
    in tag_inst.get_unique_with_word_tags(word=" the ", )
]
# Out:
# 1.4 ms ± 231 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# ## `User` class:

# %% [markdown]
# Create `User` class instance:

# %%
user_inst: User = User(file_path="../data/datasets/", )

# %%
# %%timeit -n 10 -r 3
user_inst: User = User(file_path="../data/datasets/", )
# Out:
# 537 ns ± 200 ns per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a dictionary of users gave a rating to how many films:

# %%
[
    print(f"User ID: {user_id}, ratings count: {ratings_cnt}.", )
    for user_id, ratings_cnt
    in user_inst.get_users_rating_counts().items()
];
# Out:
# User ID: 2, ratings count: 29.
# User ID: 3, ratings count: 39.
# User ID: 5, ratings count: 44.
# User ID: 7, ratings count: 126.
# User ID: 4, ratings count: 216.
# User ID: 1, ratings count: 232.
# User ID: 6, ratings count: 314.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings count: {ratings_cnt}.", )
    for user_id, ratings_cnt
    in user_inst.get_users_rating_counts().items()
]
# Out:
# 2.2 ms ± 122 μs per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %% [markdown]
# Get a users metric values:

# %%
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="min", ).items()
];
# Out:
# User ID: 2, ratings metric: 2.0.
# User ID: 1, ratings metric: 1.0.
# User ID: 4, ratings metric: 1.0.
# User ID: 5, ratings metric: 1.0.
# User ID: 6, ratings metric: 1.0.
# User ID: 3, ratings metric: 0.5.
# User ID: 7, ratings metric: 0.5.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="min", ).items()
]
# Out:
# 73.1 ms ± 7.13 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="max", ).items()
];
# Out:
# User ID: 1, ratings metric: 5.0.
# User ID: 2, ratings metric: 5.0.
# User ID: 3, ratings metric: 5.0.
# User ID: 4, ratings metric: 5.0.
# User ID: 5, ratings metric: 5.0.
# User ID: 6, ratings metric: 5.0.
# User ID: 7, ratings metric: 5.0.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="max", ).items()
]
# Out:
# 70.8 ms ± 3.94 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="mean", ).items()
];
# Out:
# User ID: 1, ratings metric: 4.37.
# User ID: 2, ratings metric: 3.95.
# User ID: 5, ratings metric: 3.64.
# User ID: 4, ratings metric: 3.56.
# User ID: 6, ratings metric: 3.49.
# User ID: 7, ratings metric: 3.35.
# User ID: 3, ratings metric: 2.44.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="mean", ).items()
]
# Out:
# 64.8 ms ± 6.05 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="median", ).items()
];
# Out:
# User ID: 1, ratings metric: 5.0.
# User ID: 2, ratings metric: 4.0.
# User ID: 4, ratings metric: 4.0.
# User ID: 5, ratings metric: 4.0.
# User ID: 7, ratings metric: 4.0.
# User ID: 6, ratings metric: 3.0.
# User ID: 3, ratings metric: 0.5.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="median", ).items()
]
# Out:
# 75.2 ms ± 2.16 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="var", ).items()
];
# Out:
# User ID: 3, ratings metric: 4.26.
# User ID: 4, ratings metric: 1.72.
# User ID: 7, ratings metric: 1.65.
# User ID: 5, ratings metric: 0.96.
# User ID: 6, ratings metric: 0.72.
# User ID: 1, ratings metric: 0.64.
# User ID: 2, ratings metric: 0.63.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="var", ).items()
]
# Out:
# 91.2 ms ± 2.05 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)

# %%
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="std", ).items()
];
# Out:
# User ID: 3, ratings metric: 2.06.
# User ID: 4, ratings metric: 1.31.
# User ID: 7, ratings metric: 1.28.
# User ID: 5, ratings metric: 0.98.
# User ID: 6, ratings metric: 0.85.
# User ID: 1, ratings metric: 0.8.
# User ID: 2, ratings metric: 0.79.

# %%
# %%timeit -n 10 -r 3
# %%capture
[
    print(f"User ID: {user_id}, ratings metric: {ratings_metric}.", )
    for user_id, ratings_metric
    in user_inst.get_top_ratings_metric_users(metric="std", ).items()
]
# Out:
# 91 ms ± 9.36 ms per loop (mean ± std. dev. of 3 runs, 10 loops each)
